# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Import the requests library.
import requests

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0f3bdfb19f71b866aaf70b60648b7b31

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "New York"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0f3bdfb19f71b866aaf70b60648b7b31&q=New York

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# create an empty list to hold the weather data
city_data =  []

#Print the beginning of the logging
print("Beginning Data Retrieval       ")
print("-------------")

#create Counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1


# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | kurilsk
# Processing Record 5 of Set 1 | nador
# Processing Record 6 of Set 1 | boke
# Processing Record 7 of Set 1 | mount gambier
# Processing Record 8 of Set 1 | chicama
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | iqaluit
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | aykino
# Processing Record 13 of Set 1 | port-gentil
# Processing Record 14 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 1 | mehamn
# Processing Record 16 of Set 1 | hami
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | mount pleasant
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | lebu
# Processing Record 21 of Set 1 | dongsheng
# Processing Record 22 of Set 1 | leshukonskoye
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | norman wells
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | luanda
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | chupa
# Processing Record 31 of Set 1 | inhambane
# Processing Record 32 of Set 1 | talnakh
# Processing Record 33 of Set 1 | alofi
# Processing Record 34 of Set 1 | dauphin
# Processing Record 35 of Set 1 | westport
# Processing Record 36 of Set 1 | katsuura
# Processing Record 37 of Set 1 | praia
# Processing Record 38 of Set 1 | baoqing
# Processing Record 39 of Set 1 | mareeba
# Processing Record 40 of Set 1 | ulaangom
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 1 | petershagen
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | belyy yar
# Processing Record 47 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | hasaki
# Processing Record 50 of Set 1 | chokurdakh
# Processing Record 1 of Set 2 | barrow
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | iguape
# Processing Record 4 of Set 2 | chuy
# Processing Record 5 of Set 2 | rio claro
# Processing Record 6 of Set 2 | rio verde de mato grosso
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | toppenish
# Processing Record 9 of Set 2 | kulu
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | klaksvik
# Processing Record 12 of Set 2 | upernavik
# Processing Record 13 of Set 2 | isangel
# Processing Record 14 of Set 2 | blytheville
# Processing Record 15 of Set 2 | osypenko
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | klyuchi
# Processing Record 18 of Set 2 | touros
# Processing Record 19 of Set 2 | menzelinsk
# Processing Record 20 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 2 | naze
# Processing Record 22 of Set 2 | golspie
# Processing Record 23 of Set 2 | broome
# Processing Record 24 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 2 | soto la marina
# Processing Record 26 of Set 2 | ipixuna
# Processing Record 27 of Set 2 | chililabombwe
# Processing Record 28 of Set 2 | torbay
# Processing Record 29 of Set 2 | yellowknife
# Processing Record 30 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 2 | cidreira
# Processing Record 32 of Set 2 | ponta do sol
# Processing Record 33 of Set 2 | bereznik
# Processing Record 34 of Set 2 | nurota
# Processing Record 35 of Set 2 | geraldton
# Processing Record 36 of Set 2 | hithadhoo
# Processing Record 37 of Set 2 | shingu
# Processing Record 38 of Set 2 | uruzgan
# Processing Record 39 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 2 | san andres
# Processing Record 41 of Set 2 | guerrero negro
# Processing Record 42 of Set 2 | victoria
# Processing Record 43 of Set 2 | saint-joseph
# Processing Record 44 of Set 2 | berlevag
# Processing Record 45 of Set 2 | east london
# Processing Record 46 of Set 2 | ligayan
# Processing Record 47 of Set 2 | belaya gora
# Processing Record 48 of Set 2 | shieli
# Processing Record 49 of Set 2 | thompson
# Processing Record 50 of Set 2 | tasiilaq
# Processing Record 1 of Set 3 | diamantino
# Processing Record 2 of Set 3 | ginir
# Processing Record 3 of Set 3 | cabo san lucas
# Processing Record 4 of Set 3 | port hardy
# Processing Record 5 of Set 3 | gorontalo
# Processing Record 6 of Set 3 | kruisfontein
# Processing Record 7 of Set 3 | kozelsk
# Processing Record 8 of Set 3 | kavaratti
# Processing Record 9 of Set 3 | port alfred
# Processing Record 10 of Set 3 | labuan
# Processing Record 11 of Set 3 | jiblah
# Processing Record 12 of Set 3 | suao
# City not found. Skipping...
# Processing Record 13 of Set 3 | vilhena
# Processing Record 14 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 3 | coihaique
# Processing Record 16 of Set 3 | tocopilla
# Processing Record 17 of Set 3 | petatlan
# Processing Record 18 of Set 3 | cape town
# Processing Record 19 of Set 3 | papasquiaro
# City not found. Skipping...
# Processing Record 20 of Set 3 | san patricio
# Processing Record 21 of Set 3 | phan thiet
# Processing Record 22 of Set 3 | khatanga
# Processing Record 23 of Set 3 | brantford
# Processing Record 24 of Set 3 | golden
# Processing Record 25 of Set 3 | ishigaki
# Processing Record 26 of Set 3 | dekar
# Processing Record 27 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 28 of Set 3 | northam
# Processing Record 29 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 3 | kodiak
# Processing Record 31 of Set 3 | massakory
# Processing Record 32 of Set 3 | maua
# Processing Record 33 of Set 3 | cayenne
# Processing Record 34 of Set 3 | mezen
# Processing Record 35 of Set 3 | nanortalik
# Processing Record 36 of Set 3 | sitka
# Processing Record 37 of Set 3 | ahipara
# Processing Record 38 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 3 | mataura
# Processing Record 40 of Set 3 | egvekinot
# Processing Record 41 of Set 3 | syamzha
# Processing Record 42 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 3 | te anau
# Processing Record 44 of Set 3 | umm durman
# City not found. Skipping...
# Processing Record 45 of Set 3 | nikolskoye
# Processing Record 46 of Set 3 | beringovskiy
# Processing Record 47 of Set 3 | kaitangata
# Processing Record 48 of Set 3 | magadan
# Processing Record 49 of Set 3 | los llanos de aridane
# Processing Record 50 of Set 3 | rincon
# Processing Record 1 of Set 4 | san luis
# Processing Record 2 of Set 4 | chiredzi
# Processing Record 3 of Set 4 | avarua
# Processing Record 4 of Set 4 | portobelo
# Processing Record 5 of Set 4 | sibolga
# Processing Record 6 of Set 4 | puerto ayora
# Processing Record 7 of Set 4 | srednekolymsk
# Processing Record 8 of Set 4 | toowoomba
# Processing Record 9 of Set 4 | poum
# Processing Record 10 of Set 4 | sao filipe
# Processing Record 11 of Set 4 | dikson
# Processing Record 12 of Set 4 | anqing
# Processing Record 13 of Set 4 | port elizabeth
# Processing Record 14 of Set 4 | jutai
# Processing Record 15 of Set 4 | bengkulu
# Processing Record 16 of Set 4 | nelson bay
# Processing Record 17 of Set 4 | avallon
# Processing Record 18 of Set 4 | korla
# Processing Record 19 of Set 4 | qaqortoq
# Processing Record 20 of Set 4 | boa vista
# Processing Record 21 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 4 | kyshtovka
# Processing Record 23 of Set 4 | ambilobe
# Processing Record 24 of Set 4 | colomi
# Processing Record 25 of Set 4 | cockburn town
# Processing Record 26 of Set 4 | bambous virieux
# Processing Record 27 of Set 4 | broken hill
# Processing Record 28 of Set 4 | lazaro cardenas
# Processing Record 29 of Set 4 | la concordia
# Processing Record 30 of Set 4 | san angelo
# Processing Record 31 of Set 4 | kalmunai
# Processing Record 32 of Set 4 | ugoofaaru
# Processing Record 33 of Set 4 | deder
# Processing Record 34 of Set 4 | constitucion
# Processing Record 35 of Set 4 | aykhal
# Processing Record 36 of Set 4 | saint albans
# Processing Record 37 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 4 | araguatins
# City not found. Skipping...
# Processing Record 39 of Set 4 | ndele
# Processing Record 40 of Set 4 | omboue
# Processing Record 41 of Set 4 | tuktoyaktuk
# Processing Record 42 of Set 4 | mayo
# Processing Record 43 of Set 4 | santa fe
# Processing Record 44 of Set 4 | georgetown
# Processing Record 45 of Set 4 | butaritari
# Processing Record 46 of Set 4 | thinadhoo
# Processing Record 47 of Set 4 | saskylakh
# Processing Record 48 of Set 4 | coos bay
# Processing Record 49 of Set 4 | pevek
# Processing Record 50 of Set 4 | maryville
# Processing Record 1 of Set 5 | ilulissat
# Processing Record 2 of Set 5 | kangaatsiaq
# Processing Record 3 of Set 5 | yablonovo
# Processing Record 4 of Set 5 | codrington
# Processing Record 5 of Set 5 | vagur
# Processing Record 6 of Set 5 | villarrobledo
# Processing Record 7 of Set 5 | worland
# Processing Record 8 of Set 5 | kpandae
# Processing Record 9 of Set 5 | krasnoselkup
# Processing Record 10 of Set 5 | dingle
# Processing Record 11 of Set 5 | kharp
# Processing Record 12 of Set 5 | puerto escondido
# Processing Record 13 of Set 5 | saint-augustin
# Processing Record 14 of Set 5 | lompoc
# Processing Record 15 of Set 5 | ostrovnoy
# Processing Record 16 of Set 5 | saint-georges
# Processing Record 17 of Set 5 | tatarskaya pishlya
# Processing Record 18 of Set 5 | provideniya
# Processing Record 19 of Set 5 | idenao
# Processing Record 20 of Set 5 | wexford
# Processing Record 21 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 5 | floro
# Processing Record 23 of Set 5 | tucuman
# Processing Record 24 of Set 5 | ibirapitanga
# Processing Record 25 of Set 5 | bathsheba
# Processing Record 26 of Set 5 | santander
# Processing Record 27 of Set 5 | faanui
# Processing Record 28 of Set 5 | gandu
# Processing Record 29 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 30 of Set 5 | lakes entrance
# Processing Record 31 of Set 5 | kupang
# Processing Record 32 of Set 5 | maykain
# City not found. Skipping...
# Processing Record 33 of Set 5 | teguise
# Processing Record 34 of Set 5 | at-bashi
# Processing Record 35 of Set 5 | trincomalee
# Processing Record 36 of Set 5 | douentza
# Processing Record 37 of Set 5 | guabito
# Processing Record 38 of Set 5 | yatou
# Processing Record 39 of Set 5 | saint george
# Processing Record 40 of Set 5 | terra santa
# Processing Record 41 of Set 5 | tabulbah
# City not found. Skipping...
# Processing Record 42 of Set 5 | saint-philippe
# Processing Record 43 of Set 5 | wheatley
# Processing Record 44 of Set 5 | hambantota
# Processing Record 45 of Set 5 | tigzirt
# Processing Record 46 of Set 5 | tiksi
# Processing Record 47 of Set 5 | bijawar
# Processing Record 48 of Set 5 | changtu
# Processing Record 49 of Set 5 | kawalu
# Processing Record 50 of Set 5 | jijiga
# Processing Record 1 of Set 6 | bandarbeyla
# Processing Record 2 of Set 6 | muros
# Processing Record 3 of Set 6 | ous
# Processing Record 4 of Set 6 | fayaoue
# Processing Record 5 of Set 6 | carnarvon
# Processing Record 6 of Set 6 | linxia
# Processing Record 7 of Set 6 | jieshi
# Processing Record 8 of Set 6 | marathon
# Processing Record 9 of Set 6 | fortuna
# Processing Record 10 of Set 6 | hargeysa
# Processing Record 11 of Set 6 | vanimo
# Processing Record 12 of Set 6 | derzhavinsk
# Processing Record 13 of Set 6 | mogadishu
# Processing Record 14 of Set 6 | pangnirtung
# Processing Record 15 of Set 6 | kirakira
# Processing Record 16 of Set 6 | whitehorse
# Processing Record 17 of Set 6 | ambon
# Processing Record 18 of Set 6 | plouzane
# Processing Record 19 of Set 6 | praya
# Processing Record 20 of Set 6 | castro
# Processing Record 21 of Set 6 | kedrovyy
# Processing Record 22 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 6 | taoudenni
# Processing Record 24 of Set 6 | nemuro
# Processing Record 25 of Set 6 | pietersburg
# Processing Record 26 of Set 6 | dunedin
# Processing Record 27 of Set 6 | kirksville
# Processing Record 28 of Set 6 | mar del plata
# Processing Record 29 of Set 6 | naryan-mar
# Processing Record 30 of Set 6 | salalah
# Processing Record 31 of Set 6 | kijang
# Processing Record 32 of Set 6 | coquimbo
# Processing Record 33 of Set 6 | ustye
# Processing Record 34 of Set 6 | fomboni
# Processing Record 35 of Set 6 | predivinsk
# Processing Record 36 of Set 6 | souillac
# Processing Record 37 of Set 6 | dudinka
# Processing Record 38 of Set 6 | havre-saint-pierre
# Processing Record 39 of Set 6 | rasskazovo
# Processing Record 40 of Set 6 | namatanai
# Processing Record 41 of Set 6 | roma
# Processing Record 42 of Set 6 | purmerend
# Processing Record 43 of Set 6 | jalu
# Processing Record 44 of Set 6 | severo-kurilsk
# Processing Record 45 of Set 6 | tsabong
# Processing Record 46 of Set 6 | moramanga
# Processing Record 47 of Set 6 | pisco
# Processing Record 48 of Set 6 | tanabi
# Processing Record 49 of Set 6 | longyearbyen
# Processing Record 50 of Set 6 | muravlenko
# Processing Record 1 of Set 7 | hof
# Processing Record 2 of Set 7 | emba
# Processing Record 3 of Set 7 | aconibe
# Processing Record 4 of Set 7 | urumqi
# Processing Record 5 of Set 7 | jedrzejow
# Processing Record 6 of Set 7 | sarh
# Processing Record 7 of Set 7 | aklavik
# Processing Record 8 of Set 7 | ketchikan
# Processing Record 9 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 7 | alpena
# Processing Record 11 of Set 7 | los lunas
# Processing Record 12 of Set 7 | ubinskoye
# Processing Record 13 of Set 7 | asau
# Processing Record 14 of Set 7 | ortakoy
# Processing Record 15 of Set 7 | sturgeon falls
# Processing Record 16 of Set 7 | majene
# Processing Record 17 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 7 | liniere
# City not found. Skipping...
# Processing Record 19 of Set 7 | vakhrushev
# Processing Record 20 of Set 7 | port macquarie
# Processing Record 21 of Set 7 | olds
# Processing Record 22 of Set 7 | kyren
# Processing Record 23 of Set 7 | oranjestad
# Processing Record 24 of Set 7 | airai
# Processing Record 25 of Set 7 | pousat
# City not found. Skipping...
# Processing Record 26 of Set 7 | coahuayana
# Processing Record 27 of Set 7 | mikuni
# Processing Record 28 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 29 of Set 7 | port lincoln
# Processing Record 30 of Set 7 | namibe
# Processing Record 31 of Set 7 | biltine
# Processing Record 32 of Set 7 | lavrentiya
# Processing Record 33 of Set 7 | sao joao da barra
# Processing Record 34 of Set 7 | liku
# Processing Record 35 of Set 7 | rorvik
# Processing Record 36 of Set 7 | cherskiy
# Processing Record 37 of Set 7 | mahebourg
# Processing Record 38 of Set 7 | rundu
# Processing Record 39 of Set 7 | auki
# Processing Record 40 of Set 7 | almenara
# Processing Record 41 of Set 7 | lasa
# Processing Record 42 of Set 7 | hovd
# Processing Record 43 of Set 7 | genhe
# Processing Record 44 of Set 7 | santa catalina
# Processing Record 45 of Set 7 | itapecerica
# Processing Record 46 of Set 7 | abha
# Processing Record 47 of Set 7 | hamilton
# Processing Record 48 of Set 7 | atlantic city
# Processing Record 49 of Set 7 | uribia
# Processing Record 50 of Set 7 | bucerias
# Processing Record 1 of Set 8 | gourdon
# Processing Record 2 of Set 8 | quesnel
# Processing Record 3 of Set 8 | itaueira
# Processing Record 4 of Set 8 | verkhnyaya tishanka
# Processing Record 5 of Set 8 | talcahuano
# Processing Record 6 of Set 8 | arman
# Processing Record 7 of Set 8 | port shepstone
# Processing Record 8 of Set 8 | hit
# Processing Record 9 of Set 8 | fairbanks
# Processing Record 10 of Set 8 | am timan
# Processing Record 11 of Set 8 | araouane
# Processing Record 12 of Set 8 | flinders
# Processing Record 13 of Set 8 | kerteh
# City not found. Skipping...
# Processing Record 14 of Set 8 | oxapampa
# Processing Record 15 of Set 8 | port pirie
# Processing Record 16 of Set 8 | praia da vitoria
# Processing Record 17 of Set 8 | ancud
# Processing Record 18 of Set 8 | kaspiyskiy
# Processing Record 19 of Set 8 | jaru
# Processing Record 20 of Set 8 | brae
# Processing Record 21 of Set 8 | puerto leguizamo
# Processing Record 22 of Set 8 | pangody
# Processing Record 23 of Set 8 | noumea
# Processing Record 24 of Set 8 | pontes e lacerda
# Processing Record 25 of Set 8 | gari
# Processing Record 26 of Set 8 | tumbes
# Processing Record 27 of Set 8 | talara
# Processing Record 28 of Set 8 | bocaiuva
# Processing Record 29 of Set 8 | bonthe
# Processing Record 30 of Set 8 | balagansk
# Processing Record 31 of Set 8 | gat
# Processing Record 32 of Set 8 | trelew
# Processing Record 33 of Set 8 | izvestkovyy
# Processing Record 34 of Set 8 | kargil
# Processing Record 35 of Set 8 | tambura
# Processing Record 36 of Set 8 | nouakchott
# Processing Record 37 of Set 8 | luderitz
# Processing Record 38 of Set 8 | oktyabrskiy
# Processing Record 39 of Set 8 | leningradskiy
# Processing Record 40 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 8 | tiassale
# Processing Record 42 of Set 8 | sosnovo-ozerskoye
# Processing Record 43 of Set 8 | meulaboh
# Processing Record 44 of Set 8 | nenjiang
# Processing Record 45 of Set 8 | esperance
# Processing Record 46 of Set 8 | baykit
# Processing Record 47 of Set 8 | teya
# Processing Record 48 of Set 8 | chernyshevskiy
# Processing Record 49 of Set 8 | addi ugri
# City not found. Skipping...
# Processing Record 50 of Set 8 | vallenar
# Processing Record 1 of Set 9 | luganville
# Processing Record 2 of Set 9 | bethel
# Processing Record 3 of Set 9 | mengcheng
# Processing Record 4 of Set 9 | vestmannaeyjar
# Processing Record 5 of Set 9 | tateyama
# Processing Record 6 of Set 9 | lopukhiv
# Processing Record 7 of Set 9 | fukue
# Processing Record 8 of Set 9 | san cristobal
# Processing Record 9 of Set 9 | sylva
# Processing Record 10 of Set 9 | huron
# Processing Record 11 of Set 9 | ibra
# Processing Record 12 of Set 9 | rio grande
# Processing Record 13 of Set 9 | narsaq
# Processing Record 14 of Set 9 | amapa
# Processing Record 15 of Set 9 | tezu
# Processing Record 16 of Set 9 | maceio
# Processing Record 17 of Set 9 | romanovo
# Processing Record 18 of Set 9 | karia
# Processing Record 19 of Set 9 | key largo
# Processing Record 20 of Set 9 | volnoye
# Processing Record 21 of Set 9 | salinopolis
# Processing Record 22 of Set 9 | maldonado
# Processing Record 23 of Set 9 | palmer
# Processing Record 24 of Set 9 | tazovskiy
# Processing Record 25 of Set 9 | aden
# Processing Record 26 of Set 9 | bilma
# Processing Record 27 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 9 | caravelas
# Processing Record 29 of Set 9 | atyrau
# Processing Record 30 of Set 9 | katha
# City not found. Skipping...
# Processing Record 31 of Set 9 | southbridge
# Processing Record 32 of Set 9 | rosarito
# Processing Record 33 of Set 9 | ixtapa
# Processing Record 34 of Set 9 | mayor pablo lagerenza
# Processing Record 35 of Set 9 | banos
# Processing Record 36 of Set 9 | rajula
# Processing Record 37 of Set 9 | huilong
# Processing Record 38 of Set 9 | san rafael
# Processing Record 39 of Set 9 | primorsk
# Processing Record 40 of Set 9 | chapais
# Processing Record 41 of Set 9 | pedernales
# Processing Record 42 of Set 9 | sidi ali
# Processing Record 43 of Set 9 | vardo
# Processing Record 44 of Set 9 | kusk
# City not found. Skipping...
# Processing Record 45 of Set 9 | nouadhibou
# Processing Record 46 of Set 9 | hervey bay
# Processing Record 47 of Set 9 | killorglin
# Processing Record 48 of Set 9 | mizdah
# Processing Record 49 of Set 9 | maymyo
# Processing Record 50 of Set 9 | trairi
# Processing Record 1 of Set 10 | pemangkat
# Processing Record 2 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 10 | yar-sale
# Processing Record 4 of Set 10 | amarante do maranhao
# Processing Record 5 of Set 10 | walvis bay
# Processing Record 6 of Set 10 | lushunkou
# City not found. Skipping...
# Processing Record 7 of Set 10 | sorong
# Processing Record 8 of Set 10 | susanville
# Processing Record 9 of Set 10 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 10 of Set 10 | karratha
# Processing Record 11 of Set 10 | krasnyy chikoy
# Processing Record 12 of Set 10 | tual
# Processing Record 13 of Set 10 | marsa matruh
# Processing Record 14 of Set 10 | komsomolskiy
# Processing Record 15 of Set 10 | qui nhon
# Processing Record 16 of Set 10 | bandiagara
# Processing Record 17 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 18 of Set 10 | ekibastuz
# Processing Record 19 of Set 10 | bukama
# Processing Record 20 of Set 10 | mvomero
# Processing Record 21 of Set 10 | puerto baquerizo moreno
# Processing Record 22 of Set 10 | buala
# Processing Record 23 of Set 10 | nalut
# Processing Record 24 of Set 10 | great yarmouth
# Processing Record 25 of Set 10 | gweta
# Processing Record 26 of Set 10 | hvide sande
# Processing Record 27 of Set 10 | saint anthony
# Processing Record 28 of Set 10 | kavieng
# Processing Record 29 of Set 10 | kushima
# Processing Record 30 of Set 10 | delijan
# Processing Record 31 of Set 10 | faya
# Processing Record 32 of Set 10 | gohana
# Processing Record 33 of Set 10 | tomatlan
# Processing Record 34 of Set 10 | mouzakion
# City not found. Skipping...
# Processing Record 35 of Set 10 | chalchuapa
# Processing Record 36 of Set 10 | vila
# Processing Record 37 of Set 10 | the valley
# Processing Record 38 of Set 10 | gunupur
# Processing Record 39 of Set 10 | hua hin
# Processing Record 40 of Set 10 | richards bay
# Processing Record 41 of Set 10 | berasia
# Processing Record 42 of Set 10 | oktyabrskoye
# Processing Record 43 of Set 10 | haflong
# Processing Record 44 of Set 10 | kaabong
# Processing Record 45 of Set 10 | kiunga
# Processing Record 46 of Set 10 | eseka
# Processing Record 47 of Set 10 | paamiut
# Processing Record 48 of Set 10 | san policarpo
# Processing Record 49 of Set 10 | payson
# Processing Record 50 of Set 10 | kresttsy
# Processing Record 1 of Set 11 | oeiras
# Processing Record 2 of Set 11 | prince rupert
# Processing Record 3 of Set 11 | rio gallegos
# Processing Record 4 of Set 11 | rapid valley
# Processing Record 5 of Set 11 | barbacoas
# Processing Record 6 of Set 11 | samarai
# Processing Record 7 of Set 11 | dibrugarh
# Processing Record 8 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 11 | tshikapa
# Processing Record 11 of Set 11 | waipawa
# Processing Record 12 of Set 11 | eydhafushi
# Processing Record 13 of Set 11 | uvarovka
# Processing Record 14 of Set 11 | ponta delgada
# Processing Record 15 of Set 11 | lorengau
# Processing Record 16 of Set 11 | mineral wells
# Processing Record 17 of Set 11 | grand-lahou
# Processing Record 18 of Set 11 | opuwo
# Processing Record 19 of Set 11 | clyde river
# Processing Record 20 of Set 11 | pacific grove
# Processing Record 21 of Set 11 | svetlaya
# Processing Record 22 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 11 | sharjah
# Processing Record 24 of Set 11 | half moon bay
# Processing Record 25 of Set 11 | vilcun
# Processing Record 26 of Set 11 | wright
# Processing Record 27 of Set 11 | teeli
# Processing Record 28 of Set 11 | salym
# Processing Record 29 of Set 11 | mamallapuram
# Processing Record 30 of Set 11 | coffs harbour
# Processing Record 31 of Set 11 | pinas
# Processing Record 32 of Set 11 | husavik
# Processing Record 33 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 11 | meadow lake
# Processing Record 35 of Set 11 | kidal
# Processing Record 36 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 37 of Set 11 | henties bay
# Processing Record 38 of Set 11 | bonfim
# Processing Record 39 of Set 11 | isiro
# Processing Record 40 of Set 11 | lata
# Processing Record 41 of Set 11 | grindavik
# Processing Record 42 of Set 11 | san ramon
# Processing Record 43 of Set 11 | quatre cocos
# Processing Record 44 of Set 11 | banda aceh
# Processing Record 45 of Set 11 | augustow
# Processing Record 46 of Set 11 | manokwari
# Processing Record 47 of Set 11 | bijar
# Processing Record 48 of Set 11 | semikarakorsk
# Processing Record 49 of Set 11 | fairmont
# Processing Record 50 of Set 11 | buraydah
# Processing Record 1 of Set 12 | kota kinabalu
# Processing Record 2 of Set 12 | sawang daen din
# Processing Record 3 of Set 12 | kununurra
# Processing Record 4 of Set 12 | cabedelo
# Processing Record 5 of Set 12 | caxias do sul
# Processing Record 6 of Set 12 | liverpool
# Processing Record 7 of Set 12 | aksarka
# Processing Record 8 of Set 12 | wuning
# Processing Record 9 of Set 12 | punta alta
# Processing Record 10 of Set 12 | belmonte
# Processing Record 11 of Set 12 | hobyo
# Processing Record 12 of Set 12 | rawah
# Processing Record 13 of Set 12 | havelock
# Processing Record 14 of Set 12 | tairua
# Processing Record 15 of Set 12 | mahdasht
# Processing Record 16 of Set 12 | sechura
# Processing Record 17 of Set 12 | nankana sahib
# Processing Record 18 of Set 12 | jubayl
# City not found. Skipping...
# Processing Record 19 of Set 12 | marfino
# Processing Record 20 of Set 12 | masterton
# Processing Record 21 of Set 12 | lokoja
# Processing Record 22 of Set 12 | jamame
# Processing Record 23 of Set 12 | shar
# Processing Record 24 of Set 12 | presidencia roque saenz pena
# Processing Record 25 of Set 12 | marand
# Processing Record 26 of Set 12 | ust-maya
# Processing Record 27 of Set 12 | kosh-agach
# Processing Record 28 of Set 12 | verkhnevilyuysk
# Processing Record 29 of Set 12 | kosino
# Processing Record 30 of Set 12 | hanzhong
# Processing Record 31 of Set 12 | grand gaube
# Processing Record 32 of Set 12 | clarence town
# Processing Record 33 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 34 of Set 12 | atar
# Processing Record 35 of Set 12 | sterling
# Processing Record 36 of Set 12 | homer
# Processing Record 37 of Set 12 | swan hill
# Processing Record 38 of Set 12 | mbanza-ngungu
# Processing Record 39 of Set 12 | bowen
# Processing Record 40 of Set 12 | bosobolo
# Processing Record 41 of Set 12 | san antonio
# Processing Record 42 of Set 12 | ballina
# Processing Record 43 of Set 12 | lima
# Processing Record 44 of Set 12 | cimahi
# Processing Record 45 of Set 12 | dasoguz
# Processing Record 46 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 12 | tolu
# Processing Record 48 of Set 12 | rawson
# Processing Record 49 of Set 12 | bom jardim
# Processing Record 50 of Set 12 | canberra
# Processing Record 1 of Set 13 | yokadouma
# Processing Record 2 of Set 13 | antalaha
# Processing Record 3 of Set 13 | ahuimanu
# Processing Record 4 of Set 13 | chara
# Processing Record 5 of Set 13 | bjornevatn
# Processing Record 6 of Set 13 | zhigansk
# Processing Record 7 of Set 13 | wanning
# Processing Record 8 of Set 13 | kommunisticheskiy
# Processing Record 9 of Set 13 | jumla
# Processing Record 10 of Set 13 | cavaillon
# Processing Record 11 of Set 13 | chlorakas
# Processing Record 12 of Set 13 | marinette
# Processing Record 13 of Set 13 | kieta
# Processing Record 14 of Set 13 | amahai
# Processing Record 15 of Set 13 | yirol
# City not found. Skipping...
# Processing Record 16 of Set 13 | galle
# Processing Record 17 of Set 13 | buchanan
# Processing Record 18 of Set 13 | goderich
# Processing Record 19 of Set 13 | pombas
# Processing Record 20 of Set 13 | benguela
# Processing Record 21 of Set 13 | santa maria
# Processing Record 22 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 13 | baruun-urt
# Processing Record 24 of Set 13 | eyl
# Processing Record 25 of Set 13 | tura
# Processing Record 26 of Set 13 | tchibanga
# Processing Record 27 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 28 of Set 13 | yumen
# Processing Record 29 of Set 13 | jaipur
# Processing Record 30 of Set 13 | kamenka
# Processing Record 31 of Set 13 | pativilca
# Processing Record 32 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 13 | susangerd
# Processing Record 34 of Set 13 | khandyga
# Processing Record 35 of Set 13 | sarangani
# Processing Record 36 of Set 13 | shimoda
# Processing Record 37 of Set 13 | vitim
# Processing Record 38 of Set 13 | lagoa
# Processing Record 39 of Set 13 | kantang
# Processing Record 40 of Set 13 | kropotkin
# Processing Record 41 of Set 13 | zaysan
# Processing Record 42 of Set 13 | iranshahr
# Processing Record 43 of Set 13 | tsogni
# Processing Record 44 of Set 13 | okhotsk
# Processing Record 45 of Set 13 | iskateley
# Processing Record 46 of Set 13 | nexo
# Processing Record 47 of Set 13 | znamenskoye
# Processing Record 48 of Set 13 | alasehir
# Processing Record 49 of Set 13 | hereford
# Processing Record 50 of Set 13 | lexington
# Processing Record 1 of Set 14 | wakkanai
# Processing Record 2 of Set 14 | pathein
# Processing Record 3 of Set 14 | yulara
# Processing Record 4 of Set 14 | toamasina
# Processing Record 5 of Set 14 | herat
# Processing Record 6 of Set 14 | kinston
# Processing Record 7 of Set 14 | sola
# Processing Record 8 of Set 14 | skelleftea
# Processing Record 9 of Set 14 | vostok
# Processing Record 10 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 11 of Set 14 | erzin
# Processing Record 12 of Set 14 | karasburg
# Processing Record 13 of Set 14 | clonakilty
# Processing Record 14 of Set 14 | kahului
# Processing Record 15 of Set 14 | srandakan
# Processing Record 16 of Set 14 | kuytun
# Processing Record 17 of Set 14 | agira
# Processing Record 18 of Set 14 | esso
# Processing Record 19 of Set 14 | la libertad
# Processing Record 20 of Set 14 | nicoya
# Processing Record 21 of Set 14 | natal
# Processing Record 22 of Set 14 | huangpu
# Processing Record 23 of Set 14 | iralaya
# Processing Record 24 of Set 14 | gijon
# Processing Record 25 of Set 14 | eskasem
# City not found. Skipping...
# Processing Record 26 of Set 14 | chanika
# Processing Record 27 of Set 14 | vao
# Processing Record 28 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 29 of Set 14 | muroto
# Processing Record 30 of Set 14 | ulaanbaatar
# Processing Record 31 of Set 14 | camacha
# Processing Record 32 of Set 14 | riberalta
# Processing Record 33 of Set 14 | katsiveli
# City not found. Skipping...
# Processing Record 34 of Set 14 | teahupoo
# Processing Record 35 of Set 14 | kintampo
# Processing Record 36 of Set 14 | sao jose da coroa grande
# Processing Record 37 of Set 14 | maningrida
# Processing Record 38 of Set 14 | nchelenge
# Processing Record 39 of Set 14 | yerbogachen
# Processing Record 40 of Set 14 | hualmay
# Processing Record 41 of Set 14 | statesboro
# Processing Record 42 of Set 14 | stanghelle
# Processing Record 43 of Set 14 | tautira
# Processing Record 44 of Set 14 | nyuksenitsa
# Processing Record 45 of Set 14 | tupi paulista
# Processing Record 46 of Set 14 | bogorodskoye
# Processing Record 47 of Set 14 | natchitoches
# Processing Record 48 of Set 14 | lovozero
# Processing Record 49 of Set 14 | nome
# Processing Record 50 of Set 14 | khani
# Processing Record 1 of Set 15 | rognan
# Processing Record 2 of Set 15 | cortland
# Processing Record 3 of Set 15 | labuhan
# Processing Record 4 of Set 15 | port-de-bouc
# Processing Record 5 of Set 15 | awjilah
# Processing Record 6 of Set 15 | netanya
# Processing Record 7 of Set 15 | yenagoa
# Processing Record 8 of Set 15 | kachikau
# City not found. Skipping...
# Processing Record 9 of Set 15 | saint-pierre
# Processing Record 10 of Set 15 | san dimas
# Processing Record 11 of Set 15 | biak
# Processing Record 12 of Set 15 | shimoni
# Processing Record 13 of Set 15 | channel-port aux basques
# Processing Record 14 of Set 15 | youkounkoun
# Processing Record 15 of Set 15 | cazaje
# City not found. Skipping...
# Processing Record 16 of Set 15 | jibuti
# Processing Record 17 of Set 15 | boddam
# Processing Record 18 of Set 15 | simpang
# Processing Record 19 of Set 15 | usinsk
# Processing Record 20 of Set 15 | abu zabad
# Processing Record 21 of Set 15 | la ronge
# Processing Record 22 of Set 15 | carauari
# Processing Record 23 of Set 15 | altamira
# Processing Record 24 of Set 15 | malartic
# Processing Record 25 of Set 15 | pagudpud
# Processing Record 26 of Set 15 | loten
# Processing Record 27 of Set 15 | cervo
# Processing Record 28 of Set 15 | rocha
# Processing Record 29 of Set 15 | honiara
# Processing Record 30 of Set 15 | mahanoro
# Processing Record 31 of Set 15 | severobaykalsk
# Processing Record 32 of Set 15 | yinchuan
# Processing Record 33 of Set 15 | reyes
# Processing Record 34 of Set 15 | colares
# Processing Record 35 of Set 15 | atakpame
# Processing Record 36 of Set 15 | shiringushi
# Processing Record 37 of Set 15 | padang
# Processing Record 38 of Set 15 | kudahuvadhoo
# Processing Record 39 of Set 15 | chumikan
# Processing Record 40 of Set 15 | conway
# Processing Record 41 of Set 15 | sisimiut
# Processing Record 42 of Set 15 | iksha
# Processing Record 43 of Set 15 | mwinilunga
# Processing Record 44 of Set 15 | kafanchan
# Processing Record 45 of Set 15 | riyadh
# Processing Record 46 of Set 15 | sobolevo
# Processing Record 47 of Set 15 | verkhoturye
# Processing Record 48 of Set 15 | freeport
# Processing Record 49 of Set 15 | college
# Processing Record 50 of Set 15 | gawler
# Processing Record 1 of Set 16 | bintulu
# Processing Record 2 of Set 16 | oron
# Processing Record 3 of Set 16 | kerch
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# convert the array of dcit to a pandas DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Jamestown  42.0970  -79.2353     60.39        54           1        9.22
# 1    Ushuaia -54.8000  -68.3000     30.20        86          40        4.61
# 2    Rikitea -23.1203 -134.9692     75.34        67          88       12.26
# 3    Kurilsk  45.2333  147.8833     37.74        97          99       18.30
# 4      Nador  35.1740   -2.9287     66.20        94          75        6.91
#
#   Country Current Description
# 0      US           clear sky
# 1      AR    scattered clouds
# 2      PF     overcast clouds
# 3      RU     overcast clouds
# 4      MA       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", 'Max Temp', "Cloudiness","Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Cloudiness  Wind Speed  \
# 0  Jamestown      US  42.0970  -79.2353     60.39           1        9.22
# 1    Ushuaia      AR -54.8000  -68.3000     30.20          40        4.61
# 2    Rikitea      PF -23.1203 -134.9692     75.34          88       12.26
# 3    Kurilsk      RU  45.2333  147.8833     37.74          99       18.30
# 4      Nador      MA  35.1740   -2.9287     66.20          75        6.91
#
#   Current Description
# 0           clear sky
# 1    scattered clouds
# 2     overcast clouds
# 3     overcast clouds
# 4       broken clouds

# %%
#CREATE THE OUTPUT FILE (csv)
output_data_file = "Weather_Database/WeatherPy_database.csv"

#export the city_data into a CSV
city_data_df.to_csv(output_data_file, index_label = "City_ID")
